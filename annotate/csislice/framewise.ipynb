# %%
csi_dir = '../../data/csi'
pic_dir = '../../data/pic'

import glob
datlist_rx0 = sorted(glob.glob(csi_dir + '/*subj[02356]*rx0*'))
datlist_rx1 = sorted(glob.glob(csi_dir + '/*subj[02356]*rx1*'))
datlist_rx2 = sorted(glob.glob(csi_dir + '/*subj[02356]*rx2*'))

piclist_cam0 = sorted(glob.glob(pic_dir + '/*subj[02356]*cam0*/*'))
piclist_cam1 = sorted(glob.glob(pic_dir + '/*subj[02356]*cam1*/*'))
piclist_cam2 = sorted(glob.glob(pic_dir + '/*subj[02356]*cam2*/*'))
piclist_cam3 = sorted(glob.glob(pic_dir + '/*subj[02356]*cam2*/*'))

# %%
import pandas as pd

df_ = pd.DataFrame.from_dict({
    'piclist_cam0': piclist_cam0, 
    'piclist_cam1': piclist_cam1, 
    'piclist_cam2': piclist_cam2, 
    'piclist_cam3': piclist_cam3, 
})

df_['env'] = df_['piclist_cam0'].apply(lambda x: x.split('/')[-2].split('_')[0][-1])
df_['subj'] = df_['piclist_cam0'].apply(lambda x: x.split('/')[-2].split('_')[1][-1])
df_['group'] = df_['piclist_cam0'].apply(lambda x: x.split('/')[-2].split('_')[2][-1])
df_['angle'] = df_['piclist_cam0'].apply(lambda x: x.split('/')[-2].split('_')[3][-1])
df_['t'] = df_['piclist_cam0'].apply(lambda x: x.split('/')[-2].split('_')[-1][-1])

# %%
df_.sort_values(['env', 'subj', 'group', 'angle', 't'], inplace=True)
df_
# Out:
#                                             piclist_cam0  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 1      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 2      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 3      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 4      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# ...                                                  ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
#
#                                             piclist_cam1  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 1      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 2      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 3      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 4      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# ...                                                  ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
#
#                                             piclist_cam2  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 1      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 2      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 3      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 4      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# ...                                                  ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
#
#                                             piclist_cam3 env subj group angle  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 1      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 2      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 3      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 4      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# ...                                                  ...  ..  ...   ...   ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
#
#        t
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 59995  4
# 59996  4
# 59997  4
# 59998  4
# 59999  4
#
# [60000 rows x 9 columns]

# %%
import pandas as pd

df = pd.DataFrame.from_dict({
    'datlist_rx0': datlist_rx0, 
    'datlist_rx1': datlist_rx1, 
    'datlist_rx2': datlist_rx2
})

# import pandas as pd

# df = pd.DataFrame.from_dict({'datlist_rx0': datlist_rx0})
# df1 = pd.DataFrame.from_dict({'datlist_rx1': datlist_rx1})

# %%
df['env'] = df['datlist_rx0'].apply(lambda x: x.split('/')[-1].split('_')[0][-1])
df['subj'] = df['datlist_rx0'].apply(lambda x: x.split('/')[-1].split('_')[1][-1])
df['group'] = df['datlist_rx0'].apply(lambda x: x.split('/')[-1].split('_')[2][-1])
df['angle'] = df['datlist_rx0'].apply(lambda x: x.split('/')[-1].split('_')[3][-1])
df['rx'] = df['datlist_rx0'].apply(lambda x: x.split('/')[-1].split('_')[4][-1])
df['t'] = df['datlist_rx0'].apply(lambda x: x.split('/')[-1].split('_')[5][-1])

# %%
df.sort_values(['env', 'subj', 'group', 'angle', 't'], inplace=True)
df
# Out:
#                                         datlist_rx0  \
# 0    ../../data/csi/env0_subj0_group0_angle0_rx0_t0
# 1    ../../data/csi/env0_subj0_group0_angle0_rx0_t1
# 2    ../../data/csi/env0_subj0_group0_angle0_rx0_t2
# 3    ../../data/csi/env0_subj0_group0_angle0_rx0_t3
# 4    ../../data/csi/env0_subj0_group0_angle0_rx0_t4
# ..                                              ...
# 595  ../../data/csi/env1_subj6_group2_angle3_rx0_t0
# 596  ../../data/csi/env1_subj6_group2_angle3_rx0_t1
# 597  ../../data/csi/env1_subj6_group2_angle3_rx0_t2
# 598  ../../data/csi/env1_subj6_group2_angle3_rx0_t3
# 599  ../../data/csi/env1_subj6_group2_angle3_rx0_t4
#
#                                         datlist_rx1  \
# 0    ../../data/csi/env0_subj0_group0_angle0_rx1_t0
# 1    ../../data/csi/env0_subj0_group0_angle0_rx1_t1
# 2    ../../data/csi/env0_subj0_group0_angle0_rx1_t2
# 3    ../../data/csi/env0_subj0_group0_angle0_rx1_t3
# 4    ../../data/csi/env0_subj0_group0_angle0_rx1_t4
# ..                                              ...
# 595  ../../data/csi/env1_subj6_group2_angle3_rx1_t0
# 596  ../../data/csi/env1_subj6_group2_angle3_rx1_t1
# 597  ../../data/csi/env1_subj6_group2_angle3_rx1_t2
# 598  ../../data/csi/env1_subj6_group2_angle3_rx1_t3
# 599  ../../data/csi/env1_subj6_group2_angle3_rx1_t4
#
#                                         datlist_rx2 env subj group angle rx  t
# 0    ../../data/csi/env0_subj0_group0_angle0_rx2_t0   0    0     0     0  0  0
# 1    ../../data/csi/env0_subj0_group0_angle0_rx2_t1   0    0     0     0  0  1
# 2    ../../data/csi/env0_subj0_group0_angle0_rx2_t2   0    0     0     0  0  2
# 3    ../../data/csi/env0_subj0_group0_angle0_rx2_t3   0    0     0     0  0  3
# 4    ../../data/csi/env0_subj0_group0_angle0_rx2_t4   0    0     0     0  0  4
# ..                                              ...  ..  ...   ...   ... .. ..
# 595  ../../data/csi/env1_subj6_group2_angle3_rx2_t0   1    6     2     3  0  0
# 596  ../../data/csi/env1_subj6_group2_angle3_rx2_t1   1    6     2     3  0  1
# 597  ../../data/csi/env1_subj6_group2_angle3_rx2_t2   1    6     2     3  0  2
# 598  ../../data/csi/env1_subj6_group2_angle3_rx2_t3   1    6     2     3  0  3
# 599  ../../data/csi/env1_subj6_group2_angle3_rx2_t4   1    6     2     3  0  4
#
# [600 rows x 9 columns]

# %%
randomer = 13928

df_.iloc[randomer][['subj', 'env', 'angle', 't']], df.iloc[randomer // 100][['subj', 'env', 'angle', 't']]
# Out:
# (subj     3
#  env      0
#  angle    3
#  t        4
#  Name: 13928, dtype: object,
#  subj     3
#  env      0
#  angle    3
#  t        4
#  Name: 139, dtype: object)

# %%
import csiread
import numpy as np
import tqdm

csilist_rx0 = list()
csilist_rx1 = list()
csilist_rx2 = list()

for i in tqdm.trange(len(df)):

    _csi0 = csiread.Intel(df.iloc[i]['datlist_rx0'], nrxnum=3, ntxnum=3, if_report=False)
    _csi0.read()
    csiarr0 = _csi0.get_scaled_csi()
    csilist_rx0.extend(np.array_split(csiarr0, 100))
    
    _csi1 = csiread.Intel(df.iloc[i]['datlist_rx1'], nrxnum=3, ntxnum=3, if_report=False)
    _csi1.read()
    csiarr1 = _csi1.get_scaled_csi()
    csilist_rx1.extend(np.array_split(csiarr1, 100))
    
    _csi2 = csiread.Intel(df.iloc[i]['datlist_rx2'], nrxnum=3, ntxnum=3, if_report=False)
    _csi2.read()
    csiarr2 = _csi2.get_scaled_csi()
    csilist_rx2.extend(np.array_split(csiarr2, 100))
# Out:
# 100%|██████████| 600/600 [03:01<00:00,  3.30it/s]

# %%
import pickle as pk
import os

csislice_dstrootdir = '/home/lscsc/caizhijie/0420-wamera-benchmark/data/frames/'

for i in tqdm.trange(len(df_)):
    # try:
    pk.dump([
        pk.load(open(df_.iloc[0]['piclist_cam0'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
        pk.load(open(df_.iloc[0]['piclist_cam1'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
        pk.load(open(df_.iloc[0]['piclist_cam2'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
        pk.load(open(df_.iloc[0]['piclist_cam3'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
        csilist_rx0[i], 
        csilist_rx1[i], 
        csilist_rx2[i]
    ], open(csislice_dstrootdir + ('_'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:])[:-4] + '.pk'), 'wb'))
    # except FileNotFoundError:
    #     if not os.path.exists(csislice_dstrootdir + '/'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:-2])):
    #         os.mkdir(csislice_dstrootdir + '/'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:-2]))
    #     if not os.path.exists(csislice_dstrootdir + '/'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:-1])):
    #         os.mkdir(csislice_dstrootdir + '/'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:-1]))
    #     pk.dump([
    #         pk.load(open(df_.iloc[0]['piclist_cam0'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
    #         pk.load(open(df_.iloc[0]['piclist_cam1'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
    #         pk.load(open(df_.iloc[0]['piclist_cam2'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
    #         pk.load(open(df_.iloc[0]['piclist_cam3'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')), 
    #         csilist_rx0[i], 
    #         csilist_rx1[i], 
    #         csilist_rx2[i]
    #     ], open(csislice_dstrootdir + ('_'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:])[:-4] + '.pk'), 'wb'))
# Out:
#  42%|████▏     | 25329/60000 [16:56<23:10, 24.93it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb Cell 9 in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> csislice_dstrootdir = '/home/lscsc/caizhijie/0420-wamera-benchmark/data/frames/'
#       <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> for i in tqdm.trange(len(df_)):
#       <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     # try:
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     pk.dump([
#       <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>         pk.load(open(df_.iloc[0]['piclist_cam0'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')),
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>         pk.load(open(df_.iloc[0]['piclist_cam1'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')),
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>         pk.load(open(df_.iloc[0]['piclist_cam2'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')),
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>         pk.load(open(df_.iloc[0]['piclist_cam3'].replace('data/', 'data/openpose/')[:-3] + 'pk', 'rb')),
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>         csilist_rx0[i],
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         csilist_rx1[i],
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>         csilist_rx2[i]
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     ], open(csislice_dstrootdir + ('_'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:])[:-4] + '.pk'), 'wb'))
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     # except FileNotFoundError:
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     #     if not os.path.exists(csislice_dstrootdir + '/'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:-2])):
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     #         os.mkdir(csislice_dstrootdir + '/'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:-2]))
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     #         csilist_rx2[i]
#      <a href='vscode-notebook-cell://ssh-remote%2Bsencing/home/lscsc/caizhijie/0420-wamera-benchmark/annotate/csislice/framewise.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>     #     ], open(csislice_dstrootdir + ('_'.join(df_.iloc[i]['piclist_cam0'].split('/')[-3:])[:-4] + '.pk'), 'wb'))
#
# KeyboardInterrupt:

# %%
df_
# Out:
#                                             piclist_cam0  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 1      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 2      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 3      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# 4      ../../data/pic/env0_subj0_group0_angle0_cam0_t...
# ...                                                  ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam0_t...
#
#                                             piclist_cam1  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 1      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 2      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 3      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# 4      ../../data/pic/env0_subj0_group0_angle0_cam1_t...
# ...                                                  ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam1_t...
#
#                                             piclist_cam2  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 1      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 2      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 3      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# 4      ../../data/pic/env0_subj0_group0_angle0_cam2_t...
# ...                                                  ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam2_t...
#
#                                             piclist_cam3 env subj group angle  \
# 0      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 1      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 2      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 3      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# 4      ../../data/pic/env0_subj0_group0_angle0_cam2_t...   0    0     0     0
# ...                                                  ...  ..  ...   ...   ...
# 59995  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59996  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59997  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59998  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
# 59999  ../../data/pic/env1_subj6_group2_angle3_cam2_t...   1    6     2     3
#
#        t
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 59995  4
# 59996  4
# 59997  4
# 59998  4
# 59999  4
#
# [60000 rows x 9 columns]

# %%
import pickle as pk

pk.dump(df_, open('framewise1.pk', 'wb'))
